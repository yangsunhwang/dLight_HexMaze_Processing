# %%
# # Script to create and save sampleframe and triframe to directory
import shapely
#from photProcessingFuncs import *
import numpy as np
import pandas as pd
import ipywidgets as widgets
#import ipympl
import csv
import matplotlib.pyplot as plt
import scipy.io
from sklearn.linear_model import Lasso
from scipy.signal import lfilter,resample,decimate,correlate
from matplotlib.lines import Line2D
#from pathlib import Path
from TriFuncs import * #custom functions for following analysis
from TriFuncs import airPLS
#get_ipython().run_line_magic('matplotlib', '')

#TODO: define pixPerCm in main jupyter notebook  before running phot_to_drames

#get variables from main script
from __main__ import *
# # Script to create and save sampleframe and triframe to directory

# %%
import matplotlib.pyplot as plt
import mplcursors
import mpldatacursor

# Sample data
x_data = [1, 2, 3, 4, 5]
y_data = [10, 14, 18, 24, 30]

# Create a scatter plot
fig, ax = plt.subplots()
scatter = ax.scatter(x_data, y_data, s=100)

# Enable zooming and panning with the toolbar
axins = ax.inset_axes([0.6, 0.6, 0.35, 0.35])
axins.scatter(x_data, y_data, s=100)

# Enable hovering to display data values
mplcursors.cursor(hover=True)

# Enable data cursor to display values interactively
mpldatacursor.datacursor(display='multiple', draggable=True)

# Customize plot appearance
ax.set_title('Interactive Plot with Zooming and Data Cursor')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

plt.show()

# %%
import numpy as np
import pandas as pd
import ipywidgets as widgets
import ipympl
import csv
import matplotlib.pyplot as plt
import scipy.io
from sklearn.linear_model import Lasso
from scipy.signal import lfilter,resample,decimate,correlate
from matplotlib.lines import Line2D
from TriFuncs import * #custom functions for following analysis
#get_ipython().run_line_magic('matplotlib', '')

#TODO: define pixPerCm in main jupyter notebook  before running phot_to_drames

#get variables from main script
from __main__ import *

# %%
import matplotlib.pyplot as plt
import mplcursors
import mpldatacursor

# Sample data
x_data = [1, 2, 3, 4, 5]
y_data = [10, 14, 18, 24, 30]

# Create a scatter plot
fig, ax = plt.subplots()
scatter = ax.scatter(x_data, y_data, s=100)

# Enable zooming and panning with the toolbar
axins = ax.inset_axes([0.6, 0.6, 0.35, 0.35])
axins.scatter(x_data, y_data, s=100)

# Enable hovering to display data values
mplcursors.cursor(hover=True)

# Enable data cursor to display values interactively
mpldatacursor.datacursor(display='multiple', draggable=True)

# Customize plot appearance
ax.set_title('Interactive Plot with Zooming and Data Cursor')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
